# %%
import pandas as pd
import geopandas as gpd
import rasterio
from shapely.geometry import Point
import random

# prendre une cartede plus haute resolution pour plus de pays
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')) 
climate_raster = 'climate_map.tif'

# %%
# Define the climate legend as a dictionary mapping RGB values to climate classes
climate_legend = {
    (0, 0, 255): "Af",      # Tropical, rainforest
    (0, 120, 255): "Am",    # Tropical, monsoon
    (70, 170, 250): "Aw",   # Tropical, savannah
    (255, 0, 0): "BWh",     # Arid, desert, hot
    (255, 150, 150): "BWk", # Arid, desert, cold
    (245, 165, 0): "BSh",   # Arid, steppe, hot
    (255, 220, 100): "BSk", # Arid, steppe, cold
    (255, 255, 0): "Csa",   # Temperate, dry summer, hot summer
    (200, 200, 0): "Csb",   # Temperate, dry summer, warm summer
    (150, 150, 0): "Csc",   # Temperate, dry summer, cold summer
    (150, 255, 150): "Cwa", # Temperate, dry winter, hot summer
    (100, 200, 100): "Cwb", # Temperate, dry winter, warm summer
    (50, 150, 50): "Cwc",   # Temperate, dry winter, cold summer
    (200, 255, 80): "Cfa",  # Temperate, no dry season, hot summer
    (100, 255, 80): "Cfb",  # Temperate, no dry season, warm summer
    (50, 200, 0): "Cfc",    # Temperate, no dry season, cold summer
    (255, 0, 255): "Dsa",   # Cold, dry summer, hot summer
    (200, 0, 200): "Dsb",   # Cold, dry summer, warm summer
    (150, 50, 150): "Dsc",  # Cold, dry summer, cold summer
    (150, 100, 150): "Dsd", # Cold, dry summer, very cold winter
    (170, 175, 255): "Dwa", # Cold, dry winter, hot summer
    (90, 120, 220): "Dwb",  # Cold, dry winter, warm summer
    (75, 80, 180): "Dwc",   # Cold, dry winter, cold summer
    (50, 0, 135): "Dwd",    # Cold, dry winter, very cold winter
    (0, 255, 255): "Dfa",   # Cold, no dry season, hot summer
    (55, 200, 255): "Dfb",  # Cold, no dry season, warm summer
    (0, 125, 125): "Dfc",   # Cold, no dry season, cold summer
    (0, 70, 95): "Dfd",     # Cold, no dry season, very cold winter
    (178, 178, 178): "ET",  # Polar, tundra
    (102, 102, 102): "EF"   # Polar, frost
}

# %%
import rasterio
from shapely.geometry import Point
import random

# Function to check if a point is within the bounds of the climate raster
def is_within_raster(lat, lon, raster_bounds):
    min_lon, min_lat, max_lon, max_lat = raster_bounds
    return min_lon <= lon <= max_lon and min_lat <= lat <= max_lat

# Function to check if a point corresponds to valid data in the raster (not NoData)
def has_valid_data(lat, lon, raster, transform, nodata_value):
    # Convert lat/lon to row/col in the raster
    col, row = ~transform * (lon, lat)
    row, col = int(row), int(col)

    # Ensure the coordinates are within the raster's bounds
    if row < 0 or col < 0 or row >= raster.shape[1] or col >= raster.shape[2]:
        return False  # Out of bounds

    # Check the raster value at this row/col to ensure it isn't NoData
    pixel_value = raster[:, row, col]
    if pixel_value[0] == nodata_value:  # Compare with the nodata value
        return False  # NoData point

    return True

# Function to generate 3 valid points (centroid + 2 valid points) per country
def generate_valid_points_for_country(country_geom, climate_raster_file, max_attempts=100):
    points = []

    # Open the climate GeoTIFF file to get bounds, transformation data, and nodata value
    with rasterio.open(climate_raster_file) as src:
        transform = src.transform
        raster_bounds = src.bounds
        climate_data = src.read()  # Read all bands (for RGB values)
        nodata_value = src.nodata  # Access the nodata value from the file

        # Step 1: Add the centroid of the country as the first point
        centroid = country_geom.centroid
        if is_within_raster(centroid.y, centroid.x, raster_bounds) and has_valid_data(centroid.y, centroid.x, climate_data, transform, nodata_value):
            points.append((centroid.y, centroid.x))  # Latitude, Longitude
        else:
            # If the centroid is out of bounds or NoData, generate a valid point inside the country's boundary
            points.append(generate_random_point_within_country(country_geom, climate_data, transform, raster_bounds, nodata_value))

        # Step 2: Generate two additional valid points inside the country and within the GeoTIFF map
        for _ in range(2):
            point = generate_random_point_within_country(country_geom, climate_data, transform, raster_bounds, nodata_value, max_attempts)
            if point is not None:
                points.append(point)
            else:
                points.append(('No valid point found', ''))  # Fallback if no valid points found
    
    return points

# Function to generate a valid random point inside the country's boundaries and within the GeoTIFF map bounds
def generate_random_point_within_country(country_geom, climate_data, transform, raster_bounds, nodata_value, max_attempts=100):
    minx, miny, maxx, maxy = country_geom.bounds
    attempts = 0

    while attempts < max_attempts:
        # Generate a random lat/lon point within the bounding box of the country
        random_point = Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
        
        # Check if the point is inside the country and within the bounds of the raster, and has valid data
        if country_geom.contains(random_point) and is_within_raster(random_point.y, random_point.x, raster_bounds):
            if has_valid_data(random_point.y, random_point.x, climate_data, transform, nodata_value):
                return (random_point.y, random_point.x)  # Return valid latitude and longitude
        
        attempts += 1

    # If no valid point is found after max_attempts, return None (or handle as needed)
    return None

country_points = {}

# Iterate through each country and generate points
for _, row in world.iterrows():
    country_name = row['name']
    country_geom = row['geometry']
    points = generate_valid_points_for_country(country_geom, climate_raster)
    country_points[country_name] = points

# %%
country_points
# Out:
# {'Fiji': [(-17.31630942638265, 163.85316464458234),
#   None,
#   (-16.68937739873093, 179.4940876865723)],
#  'Tanzania': [(-6.257732428506092, 34.75298985475595),
#   (-4.2630597701755875, 34.08615503891083),
#   (-2.6197308134879957, 34.449665828344365)],
#  'W. Sahara': [(24.291172960208623, -12.13783111160779),
#   (26.596919593339038, -9.800409280440071),
#   (23.151140023031687, -13.639810704888728)],
#  'Canada': [(61.46907614534896, -98.14238137209708),
#   (82.58596272277144, -84.30055273668441),
#   (58.26212367553686, -63.35221397945749)],
#  'United States of America': [(45.70562800215178, -112.5994359115045),
#   (65.40840842295935, -146.16216108879448),
#   (32.628553393687255, -93.87682836741232)],
#  'Kazakhstan': [(48.19166075218232, 67.2846109811001),
#   (47.47350056596062, 51.337971701420514),
#   (53.884492911493936, 62.207334545857094)],
#  'Uzbekistan': [(41.748602664652246, 63.20363952823182),
#   (40.86284694517233, 63.06296446004664),
#   (43.34384938080679, 57.945712391605625)],
#  'Papua New Guinea': [(-6.451644514630347, 145.31757462782247),
#   (-4.474088741131881, 143.784096803128),
#   (-6.286472394562405, 141.29666379137416)],
#  'Indonesia': [(-2.221737936520542, 117.42340756227364),
#   (-1.0844427063390185, 113.86344337477502),
#   (-8.236472062314215, 117.96283939377601)],
#  'Argentina': [(-35.4468214894951, -65.17536077114173),
#   (-42.35136688140646, -71.79094288195724),
#   (-54.78146921047282, -67.14975075753466)],
#  'Chile': [(-39.04701430994844, -71.5206439451643),
#   (-22.005041087906612, -68.70614180663077),
#   (-54.33252090007287, -70.23219999755176)],
#  'Dem. Rep. Congo': [(-2.8502757110956667, 23.582955831479083),
#   (-7.811078047949502, 25.41975759026125),
#   (-5.602501368529164, 15.183564424981894)],
#  'Somalia': [(4.752347756504953, 45.72670076723565),
#   (0.02310040935098545, 42.84813192305287),
#   (2.7002282461197398, 41.18286312773425)],
#  'Kenya': [(0.5959662521769523, 37.791555286661385),
#   (-0.18932477791686253, 40.762380996197756),
#   (3.205131907669828, 39.98693195212366)],
#  'Sudan': [(15.990585003116717, 29.862604012257922),
#   (20.620546114149956, 27.12897238915327),
#   (15.263729691194124, 30.003457318496075)],
#  'Chad': [(15.328867399839682, 18.581329525332894),
#   (7.528702464946803, 15.691945820294759),
#   (12.976213147422104, 17.049704854571736)],
#  'Haiti': [(18.900700691843337, -72.65801330535574),
#   (18.26425913348781, -72.75178107302528),
#   (19.330463086449896, -72.53428927222348)],
#  'Dominican Rep.': [(18.884487087982258, -70.46235845697531),
#   (18.031847743024446, -71.17720191570562),
#   (18.66343734771294, -71.05656041973644)],
#  'Russia': [(61.961663494923, 96.80331818290134),
#   (51.45569239384071, 44.16562046147277),
#   (52.90311850966227, 102.6787365958628)],
#  'Bahamas': [(25.515491725336624, -77.92997080393516),
#   (24.37775197842755, -77.84545150106982),
#   (24.03051645616428, -77.72713158023724)],
#  'Falkland Is.': [(-51.71322176551185, -59.42097279311021),
#   (-52.11475451020411, -59.24224266932891),
#   (-51.97530581696515, -59.496378070227905)],
#  'Norway': [(69.15685630975351, 15.468119955206761),
#   (78.26598928618466, 12.65631744982532),
#   (61.15240130664215, 10.356182674260356)],
#  'Greenland': [(74.77048769398986, -41.50018111492097),
#   (70.72359921041718, -34.31119176552809),
#   (79.00808255576037, -52.17246589845881)],
#  'Fr. S. Antarctic Lands': [(-49.306454911671985, 69.5315804704237),
#   (-49.24610662661307, 70.29888399342835),
#   (-48.91649834902259, 69.28602377555991)],
#  'Timor-Leste': [(-8.767760362467003, 125.96630027368401),
#   (-8.753752298975915, 125.64182827716823),
#   (-8.362253908538328, 127.09344512232968)],
#  'South Africa': [(-28.947033259979115, 25.048013879861678),
#   (-27.862865482734282, 20.534531834355484),
#   (-27.773674696003628, 22.64034069677456)],
#  'Lesotho': [(-29.625290493692013, 28.170105295170494),
#   (-29.559785194643297, 28.148287478450325),
#   (-29.418722678191656, 28.00543985730783)],
#  'Mexico': [(23.935371902244835, -102.5763495239869),
#   (22.98734344913501, -100.76208649159591),
#   (23.590175425270978, -97.77433754483364)],
#  'Uruguay': [(-32.780904365230825, -56.003278666548475),
#   (-33.735146772378975, -54.44600154841896),
#   (-31.075825702203655, -57.62517469781249)],
#  'Brazil': [(-10.806773643498916, -53.05434003576711),
#   (-12.588248890339681, -49.4010404642699),
#   (-17.423084770519544, -41.8369831352016)],
#  'Bolivia': [(-16.72898701530584, -64.64140560603113),
#   (-17.429901064486913, -66.90328574742323),
#   (-19.258434433304227, -62.43873110942464)],
#  'Peru': [(-9.191562905134553, -74.39180581684722),
#   (-5.439711010626755, -78.85263828913016),
#   (-2.8132190079203134, -76.65351236790093)],
#  'Colombia': [(3.927213862709704, -73.07773208697478),
#   (10.159555659236972, -74.53190917346795),
#   (11.14409149526512, -73.42866678129631)],
#  'Panama': [(8.530019388864652, -80.10916483549376),
#   (7.588260158804185, -77.87696235745446),
#   (7.478796256149587, -80.88208371784245)],
#  'Costa Rica': [(9.965671127464528, -84.17542309600948),
#   (10.105704572695412, -85.5327224503237),
#   (9.608638923725517, -83.16688169800163)],
#  'Nicaragua': [(12.848190428036988, -85.02031850080252),
#   (12.558134712845654, -85.29963096699689),
#   (11.06507063263239, -84.27276335362157)],
#  'Honduras': [(14.822947081652929, -86.58996383801542),
#   (14.845868568097362, -86.26773818675207),
#   (14.027800373378447, -87.17800989566808)],
#  'El Salvador': [(13.726091625794197, -88.87290317032377),
#   (14.024632054214674, -89.32552464573983),
#   (13.252815352260205, -88.13379261051949)],
#  'Guatemala': [(15.699360612026911, -90.36945836053154),
#   (16.034755343867474, -90.04664342276594),
#   (15.936001758905762, -89.97870687503382)],
#  'Belize': [(17.197089911451545, -88.70342125299318),
#   (16.876378459231255, -88.38834486573238),
#   (18.04535307966133, -88.19790316866492)],
#  'Venezuela': [(7.162132267639002, -66.16382727830238),
#   (9.805681156462843, -72.10811258444846),
#   (8.89202291024201, -62.04384662834922)],
#  'Guyana': [(4.790225375174759, -58.97120310856251),
#   (3.1623995429407445, -58.12637023855982),
#   (3.2785636256018154, -57.453292567033955)],
#  'Suriname': [(4.1200080317588865, -55.91145629952073),
#   (3.4964969796005434, -54.2848059239464),
#   (4.892508291483844, -57.48926598518918)],
#  'France': [(42.46070432663372, -2.8766966992706267),
#   (43.692799322910446, 6.00524794359638),
#   (44.66180656758979, -0.445048741442271)],
#  'Ecuador': [(-1.4547717055405804, -78.38416674608374),
#   (-1.682815192196435, -79.08531168037673),
#   (-1.3802583105699662, -77.44252423365526)],
#  'Puerto Rico': [(18.2372245709719, -66.47922227695507),
#   (18.063084193045565, -66.50625833279912),
#   (18.40441371110441, -66.67101270390707)],
#  'Jamaica': [(18.137636127868436, -77.32425480164892),
#   (18.034794550077915, -76.7463098498004),
#   (17.87231837469957, -77.26315701530747)],
#  'Cuba': [(21.631751541025228, -78.96068490970256),
#   (20.832205347791493, -77.23556945089776),
#   (22.25970964826049, -83.39468999268945)],
#  'Zimbabwe': [(-18.906987947858802, 29.788548371892524),
#   (-20.60893365818912, 30.36575102918873),
#   (-19.61235436073567, 30.455745189765913)],
#  'Botswana': [(-22.099711378826413, 23.773081465789428),
#   (-26.19372673138947, 20.989626277262268),
#   (-19.631939334872367, 25.92032395028388)],
#  'Namibia': [(-22.099776931731068, 17.156168126194093),
#   (-19.160044250337133, 19.578422370384008),
#   (-27.250487112282052, 16.57488372621973)],
#  'Senegal': [(14.354139988452022, -14.50980278585943),
#   (13.927552463541737, -15.673681959294099),
#   (12.982326488013873, -16.541609253869975)],
#  'Mali': [(17.267772061700715, -3.543294339453343),
#   (19.159067649144816, -5.192594204430638),
#   (14.852903981402013, -5.6952938582129695)],
#  'Mauritania': [(20.20926720635376, -10.326396925234992),
#   (19.90672060988672, -16.165639082034378),
#   (20.484551794921913, -10.151658532092107)],
#  'Benin': [(9.647430780663699, 2.337377553496156),
#   (6.510133149915116, 2.2553263254108478),
#   (10.961628330102872, 2.7023955655183762)],
#  'Niger': [(17.345552814745542, 9.324427099857923),
#   (14.666835135540131, 2.694262005801164),
#   (20.30176652952328, 11.479708148082304)],
#  'Nigeria': [(9.548318418209965, 7.995127754089786),
#   (5.2299142633555125, 5.423637390195719),
#   (10.63246224438857, 10.880542770827088)],
#  'Cameroon': [(5.663095287992696, 12.611551546501774),
#   (10.03849423853464, 14.930457147232985),
#   (8.544985556453469, 13.465600356014232)],
#  'Togo': [(8.439541954669616, 0.9964039436703582),
#   (7.377612062036039, 1.0887480112461667),
#   (9.020476526861248, 0.6401350502135534)],
#  'Ghana': [(7.928651813099648, -1.2369685557063992),
#   (5.282577966248762, -0.7324889771069563),
#   (10.290542934232052, -1.797522128991073)],
#  "Côte d'Ivoire": [(7.5537550070104915, -5.6120436452252225),
#   (5.33525532719894, -6.689797409536098),
#   (6.69259046051385, -6.536663184285166)],
#  'Guinea': [(10.44827287727134, -11.060853741185456),
#   (12.030286361487004, -11.831243729987815),
#   (11.667852916776411, -11.570657134667563)],
#  'Guinea-Bissau': [(12.022704382325685, -15.110623751667879),
#   (11.802343058403856, -13.789094950103081),
#   (11.84569094892576, -15.376308119028703)],
#  'Liberia': [(6.431619862252993, -9.410836154371117),
#   (6.024310265872355, -9.368215640899773),
#   (4.9744686907983455, -8.87202086094069)],
#  'Sierra Leone': [(8.53035372615305, -11.795257428559948),
#   (8.743022049108864, -10.729450594315093),
#   (8.335486455888137, -12.739741241246021)],
#  'Burkina Faso': [(12.311650494136712, -1.77653745205594),
#   (10.428307892205774, -5.379347051169537),
#   (11.598171674276484, -1.4111865538039483)],
#  'Central African Rep.': [(6.5427787059213145, 20.374347291243915),
#   (7.374721905139787, 18.281070276917863),
#   (6.3757164333638165, 15.56302574752218)],
#  'Congo': [(-0.8378010872252886, 15.13446176741353),
#   (1.7772150128574706, 16.893915332519196),
#   (-0.7545751973352974, 16.361591397884954)],
#  'Gabon': [(-0.6470481398040288, 11.687751174902044),
#   (-1.7733245624832241, 9.879496036849883),
#   (-1.7966726259326156, 11.05178819046917)],
#  'Eq. Guinea': [(1.6458643199600753, 10.366031325064027),
#   (1.7213922741513108, 11.124659624023561),
#   (1.1751379510047133, 10.61178158603338)],
#  'Zambia': [(-13.395067553524187, 27.727591918760577),
#   (-8.817835406554648, 31.242658274758124),
#   (-15.293855332611418, 28.183560785901996)],
#  'Malawi': [(-13.172834992341919, 34.193605326922366),
#   (-15.934050994323298, 34.531320708778),
#   (-11.405872598474081, 34.51419920293252)],
#  'Mozambique': [(-17.230448975659677, 35.47261597864435),
#   (-23.801633946520212, 34.19074714225342),
#   (-14.787369236638817, 30.563154360084358)],
#  'eSwatini': [(-26.48985528852001, 31.39525590206532),
#   (-26.378869623094612, 31.551947447549892),
#   (-26.95444828833905, 31.214314293657115)],
#  'Angola': [(-12.245869036133188, 17.47057255231345),
#   (-14.677073713046655, 13.983412376027593),
#   (-16.421910794460853, 18.728612019738833)],
#  'Burundi': [(-3.3773910753554657, 29.91389229542573),
#   (-2.86246747368204, 30.319362113098784),
#   (-2.3905932422708487, 30.056608312871283)],
#  'Israel': [(31.4849193900197, 35.003851206429005),
#   (30.21495428311859, 34.70021569417501),
#   (32.249671986344055, 34.89491501207889)],
#  'Lebanon': [(33.91182720781994, 35.87098632001643),
#   (34.3361310406652, 36.092324946449835),
#   (34.56806794877163, 35.97527310586031)],
#  'Madagascar': [(-19.356114077828778, 46.69117091471639),
#   (-17.626349887324714, 44.18336901539314),
#   (-21.192384836570383, 48.26722718927507)],
#  'Palestine': [(31.94113662241515, 35.27331962289024),
#   (31.605630366444686, 35.445408478423),
#   (31.643403425953696, 35.4512621157262)],
#  'Gambia': [(13.47533435870166, -15.431872807730837),
#   (13.411512815431072, -14.392770243681266),
#   (13.327191826580057, -14.728308209278083)],
#  'Tunisia': [(34.172939036882376, 9.534716120695835),
#   (33.79947931394369, 7.975040903547548),
#   (34.03929306377296, 8.526290213086595)],
#  'Algeria': [(28.185481278657537, 2.5980477916183444),
#   (23.991482138633174, 7.145190125566845),
#   (34.11828477282525, 1.9557840547872907)],
#  'Jordan': [(31.245490584748417, 36.77945490632519),
#   (30.428108104834646, 36.843680591273724),
#   (29.35871197091368, 35.90875368569851)],
#  'United Arab Emirates': [(23.86863365334761, 54.20671476159633),
#   (23.58842153913497, 54.65115034632902),
#   (23.636822297007015, 52.41205960995626)],
#  'Qatar': [(25.32185097420669, 51.1835025789133),
#   (25.250058533553794, 51.30736745231438),
#   (24.790565813272583, 50.99528444294204)],
#  'Kuwait': [(29.307266634033564, 47.600098887626416),
#   (29.45379924052834, 47.24644948336737),
#   (28.855842921473133, 47.565938268744624)],
#  'Iraq': [(33.03682096372491, 43.75691096461423),
#   (30.108450782245825, 46.5895110933919),
#   (31.10870190850877, 45.18609598813012)],
#  'Oman': [(20.611174374229545, 56.09867281997542),
#   (18.110751350206147, 56.4985051319533),
#   (17.158541290827593, 54.578684087590474)],
#  'Vanuatu': [(-15.542677057554924, 167.07375126822674),
#   (-16.178737051433732, 167.40182195045867),
#   (-16.259776264932093, 167.58556908727854)],
#  'Cambodia': [(12.684728629393506, 104.87608532525192),
#   (13.13516442417869, 103.11915108753918),
#   (14.13000554782439, 106.39511645005928)],
#  'Thailand': [(15.01697499141648, 101.00613354626108),
#   (18.782248629804094, 98.2153599529785),
#   (17.840789049350025, 103.38268696552339)],
#  'Laos': [(18.444978089036088, 103.75025989504465),
#   (21.707756739821743, 102.69912956861444),
#   (20.21077905279886, 102.84362819008336)],
#  'Myanmar': [(21.016999873773827, 96.50584094206161),
#   (21.27493873964326, 98.45650868467021),
#   (23.944052153827492, 98.21192982476413)],
#  'Vietnam': [(16.657937753254938, 106.28584079705195),
#   (21.583434070385707, 107.29102894358067),
#   (19.989041916015072, 106.04896529527471)],
#  'North Korea': [(40.14302033650109, 127.16501590888976),
#   (38.50437753934188, 125.6800870028579),
#   (40.8446132135112, 128.73467840618187)],
#  'South Korea': [(36.42759860415487, 127.8213171283307),
#   (36.52134105881735, 126.96980092197387),
#   (37.44767002769897, 126.85995581791856)],
#  'Mongolia': [(46.82368112626357, 102.94640620846634),
#   (48.643020943219824, 104.61189729090128),
#   (47.62378292750891, 96.34209943712084)],
#  'India': [(22.92500640740852, 79.59370376325381),
#   (29.126013212596344, 96.19355551884394),
#   (15.602940002888385, 80.09350667776027)],
#  'Bangladesh': [(23.83946179534406, 90.26792827719598),
#   (23.162320585033342, 91.30754319555764),
#   (22.078444148459194, 92.05142829417872)],
#  'Bhutan': [(27.427968649102027, 90.4724248062037),
#   (27.437988255338485, 90.86402896293096),
#   (26.894490201658083, 90.97125973121521)],
#  'Nepal': [(28.23944001904935, 84.01317367692529),
#   (27.393400546427337, 83.96425326620572),
#   (27.219321182942974, 85.86361788190419)],
#  'Pakistan': [(29.973460025547393, 69.41399806318127),
#   (35.62262903985827, 76.86419465221057),
#   (27.504820906559406, 68.33878838723521)],
#  'Afghanistan': [(33.85639928169076, 66.08669022192831),
#   (36.901948300501935, 68.22626533040192),
#   (35.84752746661603, 70.58222098947978)],
#  'Tajikistan': [(38.58308146421082, 71.03443504896113),
#   (39.28062312399543, 71.1024191245232),
#   (39.29113569733027, 70.67923177515812)],
#  'Kyrgyzstan': [(41.50689371318262, 74.62040481092558),
#   (41.28083768833811, 73.25318193927504),
#   (41.779356886641835, 73.13382718140572)],
#  'Turkmenistan': [(39.09124018017583, 59.27543026236141),
#   (37.9646718789498, 55.10248118381756),
#   (39.09625703863841, 57.1401610667769)],
#  'Iran': [(32.51891731762539, 54.285451496891426),
#   (33.41266627662077, 56.01134623915717),
#   (30.315128328710834, 53.88816728540818)],
#  'Syria': [(35.012614281129, 38.54423941961137),
#   (32.38632984522283, 36.9538712392434),
#   (33.12531046159325, 37.08197525162984)],
#  'Armenia': [(40.21660761230143, 45.00029001101479),
#   (40.3730908047913, 44.67256544983259),
#   (39.47495630880374, 46.366293542077585)],
#  'Sweden': [(62.811484968080336, 16.59626584684802),
#   (60.72374636932235, 17.525068618445452),
#   (65.12465706376962, 15.76855037531228)],
#  'Belarus': [(53.50634479481114, 27.98135261544803),
#   (53.204684923391184, 25.61008578686013),
#   (53.85164305507079, 28.603965526802497)],
#  'Ukraine': [(49.14882260840351, 31.229122070266495),
#   (49.998167146012605, 25.824197290576727),
#   (46.92183646081236, 36.62855447173767)],
#  'Poland': [(52.14826021933187, 19.31101430844868),
#   (50.647382824298205, 22.65001686412535),
#   (49.67719974111224, 21.226904825478748)],
#  'Austria': [(47.6139487927463, 14.076158884337072),
#   (47.411245811532986, 16.00310105799281),
#   (48.30149659649762, 13.109593410744038)],
#  'Hungary': [(47.19995117195427, 19.357628627745918),
#   (47.21939612718401, 16.95466780517225),
#   (47.545473283007055, 17.924195097057588)],
#  'Moldova': [(47.20367642606752, 28.41048279080328),
#   (46.37266511171912, 28.88320379937933),
#   (47.31622504949794, 27.852721182755726)],
#  'Romania': [(45.857101035738005, 24.943252494635377),
#   (45.84776879854471, 23.603689805775115),
#   (45.714441812502976, 27.954565306403232)],
#  'Lithuania': [(55.284319484766066, 23.88064027584349),
#   (55.126391390141315, 24.86856452549233),
#   (55.59168534517532, 25.50675371871458)],
#  'Latvia': [(56.80717513427924, 24.833296149803438),
#   (55.99381941435601, 27.435970480006976),
#   (56.364521554529276, 27.666184993242215)],
#  'Estonia': [(58.643695426630906, 25.824725613026608),
#   (58.06349061730923, 25.921024178170505),
#   (59.48853815833519, 24.951118443808877)],
#  'Germany': [(51.13372269040778, 10.288485092742851),
#   (52.22416483582025, 11.696017519425626),
#   (51.247839648748545, 13.516055880061806)],
#  'Bulgaria': [(42.7531187620217, 25.19511095327711),
#   (42.56144608462423, 23.594745981560656),
#   (42.981124622260836, 26.24119250777502)],
#  'Greece': [(39.066715899713955, 22.719813447095053),
#   (35.58080896190359, 23.673833019240675),
#   (38.10943713086411, 23.367843607247178)],
#  'Turkey': [(39.06837194061471, 35.116900150938406),
#   (39.21807369594173, 42.71755476808616),
#   (39.96424904005516, 41.19807248688622)],
#  'Albania': [(41.141353306048785, 20.03242643144321),
#   (42.229621329210694, 20.29782403332936),
#   (40.22374845145482, 20.48275666530212)],
#  'Croatia': [(45.01623399593114, 16.566189771645533),
#   (44.65549062089186, 15.611507382599145),
#   (45.29392271656747, 17.053555820025572)],
#  'Switzerland': [(46.79173768366762, 8.118300613385486),
#   (46.13627274685956, 8.85924797483279),
#   (46.50099469440742, 9.537567521329288)],
#  'Luxembourg': [(49.76570507415103, 5.965223432343999),
#   (49.953361238865476, 5.972163115696321),
#   (49.80539006157236, 5.856103660852729)],
#  'Belgium': [(50.65244095902296, 4.580834113854935),
#   (50.7068924683335, 4.974014771178384),
#   (50.77253639210745, 3.474307721435741)],
#  'Netherlands': [(52.298700374441786, 5.512217100965399),
#   (52.28172553719103, 5.778950323178316),
#   (52.19854911530767, 5.02574990866753)],
#  'Portugal': [(39.63404977497817, -8.055765588295687),
#   (38.784018744441404, -8.03872955529847),
#   (41.880674747571966, -6.721404285003815)],
#  'Spain': [(40.348656106226734, -3.6170206023873743),
#   (40.12105834636672, -3.01547067487751),
#   (39.79883579517989, -5.311029383741533)],
#  'Ireland': [(53.18059120995006, -8.010236544877012),
#   (52.25508538318118, -9.158079397141211),
#   (52.2198518443687, -7.089209091079448)],
#  'New Caledonia': [(-21.26135761252651, 165.53447460087543),
#   (-21.58133849015157, 166.14473817789332),
#   (-20.413690798388213, 164.816238021009)],
#  'Solomon Is.': [(-8.852497470848528, 159.9666154474296),
#   (-7.644747221366133, 158.8312904369875),
#   (-8.727038681590566, 161.00582430141287)],
#  'New Zealand': [(-41.662578757158684, 172.70192594405574),
#   (-43.35293651008429, 172.58455663418434),
#   (-41.996765427750326, 173.0023892991133)],
#  'Australia': [(-25.730654779726077, 134.50277547536595),
#   (-31.1957014130536, 146.61562372420082),
#   (-12.861316660113612, 132.94481981089785)],
#  'Sri Lanka': [(7.700534417248105, 80.66723574931648),
#   (7.099456983257254, 79.86029967491018),
#   (8.584421578676952, 80.89071778144641)],
#  'China': [(36.555066531858685, 103.88361230063249),
#   (33.25685552980347, 100.87109878240008),
#   (41.07734231633327, 87.52426726642284)],
#  'Taiwan': [(23.740964979784938, 120.97480073748623),
#   (23.28663231387576, 121.00681382778896),
#   (23.67432677768439, 120.20245555834347)],
#  'Italy': [(42.751183052964265, 12.140788372235871),
#   (45.87146368823596, 13.12854208958507),
#   (42.836221527584236, 11.597684340661829)],
#  'Denmark': [(56.06393446179454, 9.876372937675002),
#   (56.99639966060736, 8.582594011008833),
#   (56.71776672757906, 9.07954937120923)],
#  'United Kingdom': [(53.91477348053706, -2.8531353951805545),
#   (57.3980644453099, -2.5107287469239807),
#   (52.12387660485997, 0.888700952421912)],
#  'Iceland': [(65.07427633529105, -18.761028770831768),
#   (65.79002801888117, -22.602612346887195),
#   (66.37541329257908, -15.82400749220341)],
#  'Azerbaijan': [(40.22069054766167, 47.553909558006055),
#   (39.580037735339324, 48.19680402270211),
#   (39.1286095410236, 45.8521858081231)],
#  'Georgia': [(42.16201501415301, 43.48154265409026),
#   (43.30125281480791, 40.68841563628247),
#   (42.26841195218522, 44.98316253933805)],
#  'Philippines': [(11.763799362297663, 122.90267236988682),
#   (9.14226791811879, 117.87047041320027),
#   (15.239782310151316, 121.2883191455031)],
#  'Malaysia': [(3.7255884257737155, 109.6981484486297),
#   (4.7735852505207, 117.91454950559246),
#   (1.3410446470031685, 113.65532940764432)],
#  'Brunei': [(4.690250542520635, 114.91510877393951),
#   (4.51019916428638, 115.24938043135543),
#   (4.560267129336893, 114.35449520711452)],
#  'Slovenia': [(46.12542205901039, 14.938152320795732),
#   (46.024582958535596, 14.290183427328635),
#   (45.511626796546516, 13.980363708819496)],
#  'Finland': [(64.50409403963651, 26.211764610296353),
#   (65.39500107705993, 29.094492618246456),
#   (63.29134127330893, 23.609638303047475)],
#  'Slovakia': [(48.7267113517275, 19.507657147433708),
#   (48.61534578964088, 20.486466209170374),
#   (49.40068546274933, 18.865062261023606)],
#  'Czechia': [(49.775245294369, 15.334558102365815),
#   (49.52592338443264, 16.356751892213378),
#   (48.70388477508357, 14.390701874074104)],
#  'Eritrea': [(15.427276751412931, 38.67818692786484),
#   (17.34980787695068, 38.58009789330411),
#   (15.33779026077819, 37.7888166109114)],
#  'Japan': [(37.66311081170466, 138.06496213270776),
#   (35.16025923303533, 135.25915183067224),
#   (41.09113423588691, 140.7408415548348)],
#  'Paraguay': [(-23.248041946292087, -58.387387833505706),
#   (-24.132087153970406, -54.414235651825486),
#   (-23.134438905695855, -60.04623963761461)],
#  'Yemen': [(15.913231950143004, 47.535044758543485),
#   (16.032162023409185, 45.012348100381416),
#   (14.652905755297136, 45.223142360536336)],
#  'Saudi Arabia': [(24.123289839105293, 44.51636376826477),
#   (31.094282293724074, 40.4658098821814),
#   (29.057321176354787, 41.713384559477895)],
#  'Antarctica': [(-80.49198288284343, 20.571000569842635),
#   (-89.56525624241415, -100.11720457259604),
#   (-79.62361797763769, -117.811816598701)],
#  'N. Cyprus': [(35.273957681259716, 33.5582859592249),
#   (35.11493960452205, 33.50582450121374),
#   (35.29250313412496, 33.25708050221054)],
#  'Cyprus': [(34.90706085094344, 33.03955380295407),
#   (34.83689400117414, 32.50002113534789),
#   (35.089030416910546, 32.68383193988953)],
#  'Morocco': [(29.885394698302058, -8.420479544549693),
#   (29.137453929563222, -9.486927234882314),
#   (25.39755316971574, -14.279326674822801)],
#  'Egypt': [(26.50661999974957, 29.844461513124415),
#   (29.209206044666722, 28.105113783255266),
#   (28.327728862116906, 32.68715725383327)],
#  'Libya': [(26.997460407020338, 17.974352779160352),
#   (22.97786220192923, 19.69412468433984),
#   (30.42855728948333, 11.066312739624387)],
#  'Ethiopia': [(8.653999188132575, 39.551255792937745),
#   (5.788709138208967, 38.94083377747077),
#   (5.267560192919081, 39.487398535514224)],
#  'Djibouti': [(11.773044395533926, 42.4980197360445),
#   (11.291019094962161, 41.77735612084898),
#   (12.245061909769355, 42.93701220907658)],
#  'Somaliland': [(9.757971805222988, 46.23074953490769),
#   (9.672814492735935, 46.26156344963961),
#   (10.096340219060242, 44.04813878624486)],
#  'Uganda': [(1.2954855035097297, 32.35755031998686),
#   (2.6423603137605722, 31.772922153004885),
#   (0.1442371165845937, 30.584332077501873)],
#  'Rwanda': [(-2.0135144658341346, 29.91896392224289),
#   (-2.379445615302794, 29.341739138012354),
#   (-1.472127521563844, 29.78252668121863)],
#  'Bosnia and Herz.': [(44.1807677629747, 17.816883270390086),
#   (44.66886917540122, 16.806323992036845),
#   (43.820121872927324, 18.061609879980686)],
#  'Macedonia': [(41.60592964714007, 21.697903375280845),
#   (41.06051139614867, 20.99018080831001),
#   (40.97483608512218, 21.372859878828102)],
#  'Serbia': [(44.23303653365162, 20.819651926382583),
#   (42.73654430238183, 22.07678079515254),
#   (44.54945586885071, 21.584414548082293)],
#  'Montenegro': [(42.78903960655908, 19.2861817215929),
#   (42.60781600512596, 19.02704181811887),
#   (42.85000363365169, 19.64952082012819)],
#  'Kosovo': [(42.579367131816994, 20.895355721342227),
#   (42.43074938610732, 21.14505400556674),
#   (42.60100508479604, 20.996233557479737)],
#  'Trinidad and Tobago': [(10.428237089201879, -61.33036691444967),
#   (10.184543832291906, -61.402839875466015),
#   (10.081406474337822, -61.28471834671747)],
#  'S. Sudan': [(7.292890133516845, 30.198617582461907),
#   (5.279813860647597, 32.88157236711902),
#   (8.666198368609033, 33.57659834004971)]}

# %%
def get_climate(lat, lon, raster, transform, raster_bounds, legend):
    min_lon, min_lat, max_lon, max_lat = raster_bounds
    # Check if lat/lon is within raster bounds
    if min_lon <= lon <= max_lon and min_lat <= lat <= max_lat:
        # Convert lat/lon to row/col in the raster
        row, col = ~transform * (lon, lat)  # lon, lat order for transformation
        row, col = int(row), int(col)
        
        # Ensure row/col are within the valid range of the raster's grid
        if 0 <= row < raster.shape[0] and 0 <= col < raster.shape[1]:
            climate_value = raster[row, col]  # Get the numeric climate classification


            
            # Map the numeric value to its Köppen-Geiger class using the legend
            #climate_type = legend.get(climate_value, 'Unknown Climate')

            
            climate_type = climate_value
        else:
            climate_type = 'No Climate Data'
    else:
        climate_type = 'No Climate Data'  # Handle out-of-bounds case
    
    return climate_type
    
def assign_climate_to_countries(country_dict, climate_raster_file, legend):
    country_climate_map = {}

    with rasterio.open(climate_raster_file) as src:
        climate_data = src.read(1)  # Read the first band of the GeoTIFF
        transform = src.transform
        raster_bounds = src.bounds

        for country, points in country_dict.items():
            if points:  # Ensure points are not None or empty
                climate_types = []
                for point in points:
                    if point:  # Ensure each point is valid (not None)
                        lat, lon = point
                        # Get the climate type for each point using the legend
                        climate_type = get_climate(lat, lon, climate_data, transform, raster_bounds, legend)
                        climate_types.append(climate_type)
                    else:
                        climate_types.append('No Point Data')
                country_climate_map[country] = climate_types
            else:
                country_climate_map[country] = ['No Points Generated']

    return country_climate_map

# Now call the function, passing the climate legend
country_climate_map = assign_climate_to_countries(country_points, climate_raster, climate_legend)


# Step 7: Display the results
for country, climates in country_climate_map.items():
    print(f"Country: {country}")
    for i, climate in enumerate(climates):
        print(f"  Point {i+1}: Climate Type: {climate}")
# Out:
# Country: Fiji
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Point Data
#   Point 3: Climate Type: No Climate Data
# Country: Tanzania
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: W. Sahara
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Canada
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: United States of America
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Kazakhstan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Uzbekistan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Papua New Guinea
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Indonesia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Argentina
#   Point 1: Climate Type: 14
#   Point 2: Climate Type: 3
#   Point 3: Climate Type: 0
# Country: Chile
#   Point 1: Climate Type: 3
#   Point 2: Climate Type: 5
#   Point 3: Climate Type: 0
# Country: Dem. Rep. Congo
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Somalia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Kenya
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Sudan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Chad
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Haiti
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Dominican Rep.
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Russia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Bahamas
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Falkland Is.
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Norway
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Greenland
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Fr. S. Antarctic Lands
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Timor-Leste
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: South Africa
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Lesotho
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Mexico
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Uruguay
#   Point 1: Climate Type: 14
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 14
# Country: Brazil
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 29
# Country: Bolivia
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 5
# Country: Peru
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Colombia
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Panama
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Costa Rica
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Nicaragua
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Honduras
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: El Salvador
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Guatemala
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Belize
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Venezuela
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Guyana
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Suriname
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: France
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: 30
# Country: Ecuador
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Puerto Rico
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Jamaica
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Cuba
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Zimbabwe
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Botswana
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Namibia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Senegal
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Mali
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Mauritania
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 30
# Country: Benin
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Niger
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Nigeria
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Cameroon
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Togo
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Ghana
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Côte d'Ivoire
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Guinea
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Guinea-Bissau
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 0
# Country: Liberia
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Sierra Leone
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Burkina Faso
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Central African Rep.
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Congo
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Gabon
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Eq. Guinea
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Zambia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Malawi
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Mozambique
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: eSwatini
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Angola
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Burundi
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Israel
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Lebanon
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Madagascar
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Palestine
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Gambia
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Tunisia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Algeria
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Jordan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: United Arab Emirates
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Qatar
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Kuwait
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Iraq
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Oman
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Vanuatu
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Cambodia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Thailand
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Laos
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Myanmar
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Vietnam
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: North Korea
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: South Korea
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Mongolia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: India
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Bangladesh
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Bhutan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Nepal
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Pakistan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Afghanistan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Tajikistan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Kyrgyzstan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Turkmenistan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Iran
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Syria
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Armenia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Sweden
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Belarus
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Ukraine
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Poland
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Austria
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Hungary
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Moldova
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Romania
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Lithuania
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Latvia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Estonia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Germany
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Bulgaria
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Greece
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Turkey
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Albania
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Croatia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Switzerland
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Luxembourg
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Belgium
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Netherlands
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Portugal
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Spain
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Ireland
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: New Caledonia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Solomon Is.
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: New Zealand
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Australia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Sri Lanka
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: China
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Taiwan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Italy
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Denmark
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: United Kingdom
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: No Climate Data
# Country: Iceland
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: Azerbaijan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Georgia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Philippines
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Malaysia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Brunei
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Slovenia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Finland
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Slovakia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Czechia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Eritrea
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Japan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Paraguay
#   Point 1: Climate Type: 6
#   Point 2: Climate Type: 7
#   Point 3: Climate Type: 4
# Country: Yemen
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Saudi Arabia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Antarctica
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: 3
#   Point 3: Climate Type: 4
# Country: N. Cyprus
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Cyprus
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Morocco
#   Point 1: Climate Type: 30
#   Point 2: Climate Type: 30
#   Point 3: Climate Type: 30
# Country: Egypt
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Libya
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Ethiopia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Djibouti
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Somaliland
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Uganda
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Rwanda
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Bosnia and Herz.
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Macedonia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Serbia
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Montenegro
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Kosovo
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
# Country: Trinidad and Tobago
#   Point 1: Climate Type: 0
#   Point 2: Climate Type: 0
#   Point 3: Climate Type: 0
# Country: S. Sudan
#   Point 1: Climate Type: No Climate Data
#   Point 2: Climate Type: No Climate Data
#   Point 3: Climate Type: No Climate Data
